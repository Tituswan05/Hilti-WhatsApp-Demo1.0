# %% [markdown]
# <a href="https://colab.research.google.com/github/Tituswan05/Hilti-WhatsApp-Demo1.0/blob/main/Backtest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install yfinance ta
# !pip install --upgrade --force-reinstall --no-cache-dir "numpy==2.0.2" "pandas==2.2.2"
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.12/dist-packages (0.2.66)
# Requirement already satisfied: ta in /usr/local/lib/python3.12/dist-packages (0.11.0)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2.3.3)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2.3.4)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2.32.4)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.12/dist-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from yfinance) (4.5.0)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.12/dist-packages (from yfinance) (3.18.2)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.12/dist-packages (from yfinance) (4.13.5)
# Requirement already satisfied: curl_cffi>=0.7 in /usr/local/lib/python3.12/dist-packages (from yfinance) (0.13.0)
# Requirement already satisfied: protobuf>=3.19.0 in /usr/local/lib/python3.12/dist-packages (from yfinance) (5.29.5)
# Requirement already satisfied: websockets>=13.0 in /usr/local/lib/python3.12/dist-packages (from yfinance) (15.0.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Requirement already satisfied: cffi>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from curl_cffi>=0.7->yfinance) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in /usr/local/lib/python3.12/dist-packages (from curl_cffi>=0.7->yfinance) (2025.10.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3.0->yfinance) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->yfinance) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->yfinance) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->yfinance) (2.5.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.23)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Collecting numpy==2.0.2
#   Downloading numpy-2.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 kB 6.1 MB/s eta 0:00:00
# Collecting pandas==2.2.2
#   Downloading pandas-2.2.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# Collecting python-dateutil>=2.8.2 (from pandas==2.2.2)
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting pytz>=2020.1 (from pandas==2.2.2)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas==2.2.2)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting six>=1.5 (from python-dateutil>=2.8.2->pandas==2.2.2)
#   Downloading six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Downloading numpy-2.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (19.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.2/19.2 MB 145.2 MB/s eta 0:00:00
# Downloading pandas-2.2.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 196.8 MB/s eta 0:00:00
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 kB 288.7 MB/s eta 0:00:00
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 509.2/509.2 kB 345.9 MB/s eta 0:00:00
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 347.8/347.8 kB 257.5 MB/s eta 0:00:00
# Downloading six-1.17.0-py2.py3-none-any.whl (11 kB)
# Installing collected packages: pytz, tzdata, six, numpy, python-dateutil, pandas
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2025.2
#     Uninstalling pytz-2025.2:
#       Successfully uninstalled pytz-2025.2
#   Attempting uninstall: tzdata
#     Found existing installation: tzdata 2025.2
#     Uninstalling tzdata-2025.2:
#       Successfully uninstalled tzdata-2025.2
#   Attempting uninstall: six
#     Found existing installation: six 1.17.0
#     Uninstalling six-1.17.0:
#       Successfully uninstalled six-1.17.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.3.4
#     Uninstalling numpy-2.3.4:
#       Successfully uninstalled numpy-2.3.4
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.9.0.post0
#     Uninstalling python-dateutil-2.9.0.post0:
#       Successfully uninstalled python-dateutil-2.9.0.post0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.3.3
#     Uninstalling pandas-2.3.3:
#       Successfully uninstalled pandas-2.3.3
# Successfully installed numpy-2.0.2 pandas-2.2.2 python-dateutil-2.9.0.post0 pytz-2025.2 six-1.17.0 tzdata-2025.2

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

import re
import io
import numpy as np
import pandas as pd
import yfinance as yf
import requests
import warnings

warnings.simplefilter(action="ignore", category=FutureWarning)

START, END            = "2020-01-01", "2025-10-28"
LOOKBACK_DAYS         = 400
INIT_HKD              = 130_000
MONTHLY_HKD           = 3_500
HKD2USD               = 7.78  # Updated based on September 26, 2025 rate
RISK_PCT              = 0.1
ATR_RATIO             = 1
ATR_TSL_MULT          = 5.0
ATR_SL_MULT           = 3.0
VOL_MULT              = 1.2
BREAKEVEN_DAYS        = 5
BREAKEVEN_PCT         = 0.0
RSI_LOW               = 40
ROLL_DAYS             = 126
ETF_LIST              = ["QQQ"]
UNIVERSE_SOURCE       = ("https://en.wikipedia.org/wiki/Nasdaq-100", "Ticker")
HEADERS               = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/115.0.0.0 Safari/537.36"
    )
}
COMMISSION            = 0.0049
PLATFORM              = 0.0050
MIN_FEE               = 1.99
SLIPPAGE_MEAN_PCT     = 0.0005
SLIPPAGE_STD_PCT      = 0.0002
MAX_POSITIONS         = 7
MAX_PER_TICKER_PCT    = 0.5

def calc_fee(qty):
    return max(qty * (COMMISSION + PLATFORM), MIN_FEE)

def apply_slippage(price, qty, vol):
    if vol == 0:
        vol = 1
    impact = 0.01 * np.sqrt(qty / vol)  # Quadratic market impact term
    rnd = np.random.normal(loc=SLIPPAGE_MEAN_PCT + impact, scale=SLIPPAGE_STD_PCT)
    return price * (1 + rnd)

def clean_tickers(raw):
    return [t for t in raw if re.fullmatch(r"[A-Z\.]{1,5}", t)]

def fetch_tickers():
    try:
        resp = requests.get(UNIVERSE_SOURCE[0], headers=HEADERS, timeout=10)
        resp.raise_for_status()
        tables = pd.read_html(io.StringIO(resp.text))
    except Exception as e:
        print(f"Warning: 無法取得成分股列表, 原因: {e}")
        return ETF_LIST.copy()
    raw = []
    for tbl in tables:
        cols = [c.lower() for c in tbl.columns.astype(str)]
        if "ticker" in cols or "symbol" in cols:
            raw.extend(tbl[UNIVERSE_SOURCE[1]].astype(str).str.upper())
            break
    current_tickers = list(dict.fromkeys(clean_tickers(raw) + ETF_LIST))
    historical_tickers = [
        'CDW', 'CCEP', 'DASH', 'MDB', 'ROP', 'SPLK', 'TTWO', 'ON', 'GEHC',
        'ALGN', 'EBAY', 'ENPH', 'JD', 'LCID', 'ZM', 'SGEN', 'ATVI', 'RIVN', 'FI',
        'PLTR', 'MSTR', 'AXON', 'APP', 'SMCI', 'ARM', 'LIN',
        'ILMN', 'MRNA', 'DLTR', 'WBA', 'SIRI',
        'TRI', 'SHOP',
        'ANSS',
        # Additional historical from 2020-2024 removals
        'BMRN', 'CTXS', 'EXPE', 'LBTYA', 'LBTYK', 'ULTA', 'WDC', 'NTAP', 'UAL', 'WTW', 'AAL',
        'FOXA', 'FOX', 'CERN', 'CHKP', 'TCOM', 'INCY', 'VRSN', 'SWKS', 'BIDU', 'MTCH', 'DOCU', 'NTES'
    ]
    all_tickers = list(dict.fromkeys(current_tickers + historical_tickers))
    return all_tickers

def flatten(df):
    if isinstance(df.columns, pd.MultiIndex):
        df.columns = df.columns.get_level_values(0)
    return df

def rsi(close, window=14):
    delta = close.diff()
    up = delta.clip(lower=0)
    down = -delta.clip(upper=0)
    ema_up = up.ewm(com=window-1, min_periods=window).mean()
    ema_down = down.ewm(com=window-1, min_periods=window).mean()
    rs = ema_up / ema_down
    return 100 - 100 / (1 + rs)

def atr(high, low, close, window=14):
    tr = pd.concat([high - low, abs(high - close.shift()), abs(low - close.shift())], axis=1).max(axis=1)
    return tr.rolling(window=window).mean()

def macd(close, fast=12, slow=26, signal=9):
    ema_fast = close.ewm(span=fast, adjust=False).mean()
    ema_slow = close.ewm(span=slow, adjust=False).mean()
    macd_line = ema_fast - ema_slow
    signal_line = macd_line.ewm(span=signal, adjust=False).mean()
    histogram = macd_line - signal_line
    return macd_line, signal_line, histogram

def add_indicators(df):
    df = flatten(df)
    df["MA100"]       = df["Close"].rolling(100, min_periods=50).mean()
    df["MA100_slope"] = df["MA100"].diff(5)
    df["Vol20"]       = df["Volume"].rolling(20, min_periods=10).mean()
    df["ATR14"]       = atr(df["High"], df["Low"], df["Close"])
    df["RSI14"]       = rsi(df["Close"])
    df["MACD"], df["MACD_Signal"], _ = macd(df["Close"])
    df["Up3Pct"]      = (df["Close"] / df["Close"].shift(3) - 1) >= 0.005
    return df.dropna()

def simple_filter(r):
    return (
        r["Close"] > r["MA100"] and
        r["MA100_slope"] > 0 and
        r["Up3Pct"] and
        r["Volume"] > r["Vol20"] * VOL_MULT and
        r["ATR14"]/r["Close"] < ATR_RATIO and
        RSI_LOW <= r["RSI14"] and
        r["MACD"] > r["MACD_Signal"]  # Added multi-factor enhancement
    )

def prepare_universe():
    lookback = (pd.to_datetime(START) - pd.Timedelta(days=LOOKBACK_DAYS)).strftime("%Y-%m-%d")
    uni = {}
    total_buy_signals = 0
    for tk in fetch_tickers():
        try:
            df = yf.download(tk, start=lookback, end=END, progress=False, auto_adjust=True)
        except Exception as e:
            print(f"Warning: Failed to download {tk}, reason: {e}")
            continue
        if df.empty: continue
        df = add_indicators(df)
        df = df[df.index >= pd.to_datetime(START)]
        if df.empty: continue
        df["Buy"] = df.apply(simple_filter, axis=1)
        total_buy_signals += df["Buy"].sum()
        uni[tk] = df
    print(f"總買入訊號數量（所有股票所有日子）：{total_buy_signals}")
    return uni

def run_backtest(uni):
    dates = sorted({d for df in uni.values() for d in df.index})
    cash = INIT_HKD / HKD2USD
    pos, trades = {}, []
    equity, edates = [], []
    last_m, dep = None, 0
    qqq = yf.download("QQQ", start=START, end=END, progress=False, auto_adjust=True)
    qqq = flatten(qqq)
    qqq["MA100"] = qqq["Close"].rolling(100, min_periods=50).mean()
    for dt in dates:
        if last_m != dt.month:
            cash += MONTHLY_HKD / HKD2USD
            dep += 1
            last_m = dt.month
        if dt in qqq.index:
            q_close = qqq.at[dt, "Close"]
            q_ma100 = qqq.at[dt, "MA100"]
            m_ok = q_close > q_ma100
        else:
            m_ok = True
        to_close = []
        for sym, p in pos.items():
            if dt not in uni[sym].index: continue
            r = uni[sym].loc[dt]
            p["high"] = max(p["high"], r["High"])
            if r["Close"] <= p["high"] - ATR_TSL_MULT * r["ATR14"]:
                reason = "TSL"
            elif r["Close"] >= p["entry_p"] * 1.50:
                reason = "TP"
            elif r["Close"] <= p["entry_p"] - ATR_SL_MULT * r["ATR14"]:
                reason = "SL"
            elif (dt - p["entry_d"]).days >= BREAKEVEN_DAYS and r["Close"] <= p["entry_p"]:
                reason = "BE"
            else:
                continue
            exec_p = apply_slippage(r["Close"], p["qty"], r["Vol20"])
            fee = calc_fee(p["qty"])
            profit_usd = (exec_p - p["entry_p"]) * p["qty"] - fee
            cash += p["qty"] * exec_p - fee
            trades.append({
                "ticker": sym,
                "entry_date": p["entry_d"],
                "entry_price": p["entry_p"],
                "exit_date": dt,
                "exit_price": exec_p,
                "profit_pct": ((exec_p - p["entry_p"]) * p["qty"] - fee) /
                              (p["entry_p"] * p["qty"]),
                "profit_usd": profit_usd,
                "reason": reason
            })
            to_close.append(sym)
        for s in to_close:
            del pos[s]
        if m_ok:
            candidates = []
            for sym, df in uni.items():
                if sym in pos or dt not in df.index:
                    continue
                row = df.loc[dt]
                if not row["Buy"]:
                    continue
                if len(df.loc[:dt, "Close"]) >= 5:
                    price_change = (row["Close"] / df.loc[:dt, "Close"].shift(5).iloc[-1] - 1) * 100
                    momentum_score = row["RSI14"] + price_change
                else:
                    momentum_score = row["RSI14"]
                candidates.append((sym, row, momentum_score, df))
            print(f"日期 {dt}: 買入候選人數量 {len(candidates)}")
            candidates.sort(key=lambda x: x[2], reverse=True)
            for sym, row, _, df in candidates[:MAX_POSITIONS]:
                if len(pos) >= MAX_POSITIONS:
                    break
                alloc = cash * MAX_PER_TICKER_PCT
                if row["ATR14"] > 0:
                    risk_qty = int((cash * RISK_PCT) / (ATR_SL_MULT * row["ATR14"]))
                    alloc_qty = int(alloc / row["Close"])
                    qty = min(risk_qty, alloc_qty)
                    if qty == 0 and alloc >= row["Close"]:
                        qty = 1
                else:
                    qty = 0
                cost = qty * row["Close"]
                if qty > 0 and cost <= cash:
                    exec_p = apply_slippage(row["Close"], qty, row["Vol20"])
                    fee = calc_fee(qty)
                    cash -= qty * exec_p + fee
                    pos[sym] = {"entry_p": exec_p, "qty": qty, "high": exec_p, "entry_d": dt}
                    print(f"買入 {sym} 于 {dt}，數量 {qty}，成本 {cost:.2f}")
                else:
                    if len(candidates) > 0:
                        print(f"跳過 {sym} 于 {dt}：qty={qty}, cost={cost:.2f}, alloc={alloc:.2f}, cash={cash:.2f}")
        equity.append(cash + sum(p["qty"] * uni[s]["Close"].loc[dt] for s, p in pos.items() if dt in uni[s].index))
        edates.append(dt)
    last_dt = edates[-1]
    for sym, p in list(pos.items()):
        if last_dt not in uni[sym].index: continue
        r = uni[sym].loc[last_dt]
        exec_p = apply_slippage(r["Close"], p["qty"], r["Vol20"])
        fee = calc_fee(p["qty"])
        profit_usd = (exec_p - p["entry_p"]) * p["qty"] - fee
        cash += p["qty"] * exec_p - fee
        trades.append({
            "ticker": sym,
            "entry_date": p["entry_d"],
            "entry_price": p["entry_p"],
            "exit_date": last_dt,
            "exit_price": exec_p,
            "profit_pct": ((exec_p - p["entry_p"]) * p["qty"] - fee) /
                          (p["entry_p"] * p["qty"]),
            "profit_usd": profit_usd,
            "reason": "EOD"
        })
        del pos[sym]
    equity[-1] = cash
    return pd.Series(equity, index=edates), trades, dep

if __name__ == "__main__":
    uni = prepare_universe()
    eq, trades, dep = run_backtest(uni)
    injected = INIT_HKD + dep * MONTHLY_HKD
    final   = eq.iloc[-1] * HKD2USD
    net     = final - injected
    win_rate= pd.Series([t["profit_pct"] for t in trades]).gt(0).mean() if trades else 0.0
    ret     = (eq.iloc[-1] - eq.iloc[0]) / eq.iloc[0] if eq.iloc[0] != 0 else 0.0
    dd      = (eq.cummax() - eq).max() / eq.cummax().max() if eq.cummax().max() != 0 else 0.0
    roll    = eq.pct_change(periods=ROLL_DAYS).dropna()
    w6, b6  = roll.min() if not roll.empty else 0.0, roll.max() if not roll.empty else 0.0
    # Added metrics
    years = (eq.index[-1] - eq.index[0]).days / 365.25
    ann_ret = (1 + ret) ** (1 / years) - 1 if years > 0 else 0.0
    daily_returns = eq.pct_change().dropna()
    sharpe = daily_returns.mean() / daily_returns.std() * np.sqrt(252) if daily_returns.std() != 0 else 0.0
    print(f"總交易筆數：{len(trades)}")
    print(f"勝率：{win_rate:.2%}")
    print(f"真實總報酬：{ret:.2%}，最大回撤：{dd:.2%}")
    print(f"年化報酬：{ann_ret:.2%}，Sharpe比率：{sharpe:.2f}")
    print(f"投入本金：HK$ {injected:,.0f}")
    print(f"期末本金：約 HK$ {final:,.0f}（淨利 HK$ {net:,.0f}）")
    print(f"半年滾動報酬 | 最差：{w6:.2%} 最佳：{b6:.2%}")
    if trades:
        print("所有買入賣出的詳細交易記錄：")
        for t in trades:
            print(t)
# Out:
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['SPLK']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['SGEN']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ATVI']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ANSS']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CTXS']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['
# 買入 SNPS 于 2022-07-29 00:00:00，數量 10，成本 3675.00
# 買入 ON 于 2022-07-29 00:00:00，數量 28，成本 1869.84
# 買入 CDW 于 2022-07-29 00:00:00，數量 5，成本 872.22
# 買入 KLAC 于 2022-07-29 00:00:00，數量 1，成本 370.47
# 日期 2022-08-01 00:00:00: 買入候選人數量 3
# 日期 2022-08-02 00:00:00: 買入候選人數量 1
# 日期 2022-08-03 00:00:00: 買入候選人數量 6
# 買入 MRNA 于 2022-08-03 00:00:00，數量 23，成本 4289.27
# 日期 2022-08-04 00:00:00: 買入候選人數量 3
# 買入 TRI 于 2022-08-04 00:00:00，數量 23，成本 2540.18
# 日期 2022-08-05 00:00:00: 買入候選人數量 1
# 日期 2022-08-08 00:00:00: 買入候選人數量 2
# 買入 SMCI 于 2022-08-08 00:00:00，數量 562，成本 3433.26
# 日期 2022-08-09 00:00:00: 買入候選人數量 2
# 買入 TEAM 于 2022-08-09 00:00:00，數量 14，成本 3904.04
# 買入 ORLY 于 2022-08-09 00:00:00，數量 43，成本 2055.46
# 日期 2022-08-10 00:00:00: 買入候選人數量 3
# 買入 KDP 于 2022-08-10 00:00:00，數量 28，成本 1019.86
# 日期 2022-08-11 00:00:00: 買入候選人數量 1
# 日期 2022-08-12 00:00:00: 買入候選人數量 3
# 日期 2022-08-15 00:00:00: 買入候選人數量 2
# 日期 2022-08-16 00:00:00: 買入候選人數量 3
# 日期 2022-08-17 00:00:00: 買入候選人數量 0
# 日期 2022-08-18 00:00:00: 買入候選人數量 3
# 日期 2022-08-19 00:00:00: 買入候選人數量 1
# 買入 CDW 于 2022-08-19 00:00:00，數量 105，成本 19006.86
# 日期 2022-08-22 00:00:00: 買入候選人數量 0
# 日期 2022-08-23 00:00:00: 買入候選人數量 1
# 買入 PDD 于 2022-08-23 00:00:00，數量 200，成本 10102.00
# 日期 2022-08-24 00:00:00: 買入候選人數量 1
# 買入 TCOM 于 2022-08-24 00:00:00，數量 556，成本 15415.24
# 日期 2022-08-25 00:00:00: 買入候選人數量 1
# 買入 ULTA 于 2022-08-25 00:00:00，數量 18，成本 7546.50
# 日期 2022-09-09 00:00:00: 買入候選人數量 1
# 買入 CSGP 于 2022-09-09 00:00:00，數量 197，成本 15448.74
# 日期 2022-09-12 00:00:00: 買入候選人數量 5
# 買入 GILD 于 2022-09-12 00:00:00，數量 128，成本 7732.65
# 買入 FI 于 2022-09-12 00:00:00，數量 35，成本 3816.75
# 買入 SBUX 于 2022-09-12 00:00:00，數量 23，成本 1907.73
# 日期 2022-11-30 00:00:00: 買入候選人數量 31
# 買入 PDD 于 2022-11-30 00:00:00，數量 270，成本 22150.80
# 買入 TCOM 于 2022-11-30 00:00:00，數量 350，成本 11128.42
# 買入 BMRN 于 2022-11-30 00:00:00，數量 55，成本 5553.90
# 買入 SHOP 于 2022-11-30 00:00:00，數量 68，成本 2779.84
# 買入 LULU 于 2022-11-30 00:00:00，數量 3，成本 1140.93
# 買入 WDAY 于 2022-11-30 00:00:00，數量 4，成本 671.60
# 買入 BKR 于 2023-09-06 00:00:00，數量 257，成本 9121.08
# 日期 2023-09-07 00:00:00: 買入候選人數量 5
# 日期 2023-09-08 00:00:00: 買入候選人數量 3
# 日期 2023-09-11 00:00:00: 買入候選人數量 4
# 買入 ABNB 于 2023-09-11 00:00:00，數量 61，成本 8987.13
# 日期 2023-09-12 00:00:00: 買入候選人數量 2
# 日期 2023-09-13 00:00:00: 買入候選人數量 2
# 日期 2023-09-14 00:00:00: 買入候選人數量 3
# 日期 2023-09-15 00:00:00: 買入候選人數量 9
# 日期 2023-09-18 00:00:00: 買入候選人數量 1
# 買入 CHTR 于 2023-09-18 00:00:00，數量 19，成本 8658.87
# 日期 2023-09-19 00:00:00: 買入候選人數量 1
# 日期 2023-09-20 00:00:00: 買入候選人數量 4
# 買入 AMGN 于 2023-09-20 00:00:00，數量 31，成本 7905.21
# 日期 2023-10-06 00:00:00: 買入候選人數量 11
# 買入 PDD 于 2023-10-06 00:00:00，數量 263，成本 27783.32
# 買入 CRWD 于 2023-10-06 00:00:00，數量 78，成本 13781.82
# 買入 PANW 于 2023-10-06 00:00:00，數量 57，成本 7030.67
# 買入 VRTX 于 2023-10-06 00:00:00，數量 9，成本 3245.58
# 買入 ZS 于 2023-10-06 00:00:00，數量 11，成本 1799.49
# 日期 2023-10-09 00:00:00: 買入候選人數量 2
# 日期 2023-10-10 00:00:00: 買入候選人數量 8
# 日期 2023-10-11 00:00:00: 買入候選人數量 6
# 日期 2023-10-12 00:00:00: 買入候選人數量 9
# 日期 2023-10-16 00:00:00: 買入候選人數量 6
# 買入 LULU 于 2023-10-16 00:00:00，數量 35，成本 14582.40
# 日期 2023-10-17 00:00:00: 買入候選人數量 6
# 日期 2023-11-03 00:00:00: 買入候選人數量 8
# 買入 DASH 于 2023-11-03 00:00:00，數量 298，成本 27562.02
# 買入 PLTR 于 2023-11-03 00:00:00，數量 732，成本 13827.48
# 買入 MELI 于 2023-11-03 00:00:00，數量 4，成本 5551.16
# 買入 SIRI 于 2023-11-03 00:00:00，數量 90，成本 4135.59
# 買入 MU 于 2023-11-03 00:00:00，數量 28，成本 2015.10
# 日期 2023-11-06 00:00:00: 買入候選人數量 4
# 日期 2023-11-07 00:00:00: 買入候選人數量 7
# 日期 2023-11-08 00:00:00: 買入候選人數量 5
# 買入 AXON 于 2023-11-08 00:00:00，數量 115，成本 26401.70
# 買入 TRI 于 2023-11-08 00:00:00，數量 105，成本 13220.80
# 買入 APP 于 2023-11-08 00:00:00，數量 167，成本 6700.04
# 買入 TTWO 于 2023-11-08 00:00:00，數量 23，成本 3299.81
# 買入 REGN 于 2023-11-08 00:00:00，數量 2，成本 1638.56
# 日期 2023-11-09 00:00:00: 買入候選人數量 3
# 日期 2023-11-10 00:00:00: 買入候選人數量 11
# 日期 2023-11-13 00:00:00: 買入候選人數量 5
# 買入 WTW 于 2023-11-13 00:00:00，數量 60，成本 14260.42
# 買入 CRWD 于 2023-11-13 00:00:00，數量 35，成本 7033.60
# 日期 2023-11-14 00:00:00: 買入候選人數量 6
# 日期 2024-11-01 00:00:00: 買入候選人數量 7
# 日期 2024-11-04 00:00:00: 買入候選人數量 6
# 買入 TEAM 于 2024-11-04 00:00:00，數量 70，成本 15327.20
# 日期 2024-11-05 00:00:00: 買入候選人數量 5
# 日期 2024-11-06 00:00:00: 買入候選人數量 37
# 買入 PLTR 于 2024-11-06 00:00:00，數量 313，成本 17380.89
# 日期 2024-11-07 00:00:00: 買入候選人數量 26
# 日期 2024-11-08 00:00:00: 買入候選人數量 17
# 日期 2024-11-11 00:00:00: 買入候選人數量 22
# 買入 APP 于 2024-11-11 00:00:00，數量 90，成本 25778.70
# 日期 2024-11-12 00:00:00: 買入候選人數量 16
# 日期 2024-11-13 00:00:00: 買入候選人數量 13
# 日期 2024-11-14 00:00:00: 買入候選人數量 4
# 日期 2024-11-15 00:00:00: 買入候選人數量 3
# 日期 2024-11-18 00:00:00: 買入候選人數量 2
# 日期 2024-11-19 00:00:00: 買入候選人數量 4
# 買入 MSTR 于 2024-11-19 00:00:00，數量 34，成本 14638.36
# 日期 2024-11-20 00:00:00: 買入候選人數量 5
# 日期 2024-11-21 00:00:00: 買入候選人數量 9
# 日期 2024-11-22 00:00:00: 買入候選人數量 6
# 日期 2024-11-25 00:00:00: 買入候選人數量 19
# 買入 DDOG 于 2024-11-25 00:00:00，數量 117，成本 18325.71
# 日期 2024-11-26 00:00:00: 買入候選人數量 3
# 日期 2024-11-27 00:00:00: 買入候選人數量 1
# 日期 2024-11-29 00:00:00: 買入候選人數量 0
# 日期 2024-12-02 00:00:00: 買入候選人數量 2
# 買入 VRSN 于 2024-12-02 00:00:00，數量 96，成本 18375.77
# 日期 2024-12-03 00:00:00: 買入候選人數量 6
# 日期 2024-12-04 00:00:00: 買入候選人數量 5
# 日期 2024-12-05 00:00:00: 買入候選人數量 4
# 日期 2024-12-06 00:00:00: 買入候選人數量 6
# 日期 2024-12-09 00:00:00: 買入候選人數量 9
# ...
# {'ticker': 'GILD', 'entry_date': Timestamp('2025-02-24 00:00:00'), 'entry_price': np.float64(108.77609282288643), 'exit_date': Timestamp('2025-03-18 00:00:00'), 'exit_price': np.float64(108.72903371969552), 'profit_pct': np.float64(-0.000523636230284966), 'profit_usd': np.float64(-16.23334440940758), 'reason': 'BE'}
# {'ticker': 'JD', 'entry_date': Timestamp('2025-01-21 00:00:00'), 'entry_price': np.float64(37.41775436359378), 'exit_date': Timestamp('2025-04-03 00:00:00'), 'exit_price': np.float64(38.77370486098628), 'profit_pct': np.float64(0.03597357779178113), 'profit_usd': np.float64(278.63245296024724), 'reason': 'TSL'}
# {'ticker': 'DLTR', 'entry_date': Timestamp('2025-05-12 00:00:00'), 'entry_price': np.float64(89.03069579419237), 'exit_date': Timestamp('2025-05-19 00:00:00'), 'exit_price': np.float64(86.645703621758), 'profit_pct': np.float64(-0.02732061232496833), 'profit_usd': np.float64(-102.15967124224336), 'reason': 'BE'}
# {'ticker': 'ASML', 'entry_date': Timestamp('2025-05-12 00:00:00'), 'entry_price': np.float64(748.6527747298555), 'exit_date': Timestamp('2025-05-19 00:00:00'), 'exit_price': np.float64(747.4242629895731), 'profit_pct': np.float64(-0.002970017363636669), 'profit_usd': np.float64(-4.447023480564885), 'reason': 'BE'}
# {'ticker': 'RIVN', 'entry_date': Timestamp('2025-05-19 00:00:00'), 'entry_price': np.float64(16.292195284247427), 'exit_date': Timestamp('2025-05-27 00:00:00'), 'exit_price': np.float64(15.377357233501934), 'profit_pct': np.float64(-0.05675957319512381), 'profit_usd': np.float64(-212.6897516714633), 'reason': 'BE'}
# {'ticker': 'MELI', 'entry_date': Timestamp('2025-05-12 00:00:00'), 'entry_price': np.float64(2505.8428289848493), 'exit_date': Timestamp('2025-06-06 00:00:00'), 'exit_price': np.float64(2484.0366378149556), 'profit_pct': np.float64(-0.008774333332673582), 'profit_usd': np.float64(-241.8581028688311), 'reason': 'BE'}
# {'ticker': 'ABNB', 'entry_date': Timestamp('2025-06-06 00:00:00'), 'entry_price': np.float64(140.67870376177285), 'exit_date': Timestamp('2025-06-11 00:00:00'), 'exit_price': np.float64(138.1384298970553), 'profit_pct': np.float64(-0.0181858711048464), 'profit_usd': np.float64(-281.4201251189319), 'reason': 'BE'}
# {'ticker': 'KLAC', 'entry_date': Timestamp('2025-06-11 00:00:00'), 'entry_price': np.float64(870.2483686141265), 'exit_date': Timestamp('2025-06-18 00:00:00'), 'exit_price': np.float64(870.027174566587), 'profit_pct': np.float64(-0.00038868544115478013), 'profit_usd': np.float64(-5.750298808173161), 'reason': 'BE'}
# {'ticker': 'MU', 'entry_date': Timestamp('2025-06-20 00:00:00'), 'entry_price': np.float64(123.4815525936406), 'exit_date': Timestamp('2025-06-30 00:00:00'), 'exit_price': np.float64(123.14925938696767), 'profit_pct': np.float64(-0.002821001084397148), 'profit_usd': np.float64(-43.194357627443246), 'reason': 'BE'}
# {'ticker': 'DASH', 'entry_date': Timestamp('2025-06-30 00:00:00'), 'entry_price': np.float64(246.60332984063825), 'exit_date': Timestamp('2025-07-08 00:00:00'), 'exit_price': np.float64(241.60194341769946), 'profit_pct': np.float64(-0.020411253977734668), 'profit_usd': np.float64(-312.0759582222052), 'reason': 'BE'}
# {'ticker': 'INTU', 'entry_date': Timestamp('2025-05-27 00:00:00'), 'entry_price': np.float64(750.1060928942587), 'exit_date': Timestamp('2025-07-10 00:00:00'), 'exit_price': np.float64(746.6459787851389), 'profit_pct': np.float64(-0.005497152311538943), 'profit_usd': np.float64(-12.370342327359358), 'reason': 'BE'}
# {'ticker': 'GFS', 'entry_date': Timestamp('2025-07-08 00:00:00'), 'entry_price': np.float64(41.6832712861117), 'exit_date': Timestamp('2025-07-14 00:00:00'), 'exit_price': np.float64(40.3796655956114), 'profit_pct': np.float64(-0.03151157886540302), 'profit_usd': np.float64(-485.99710548511024), 'reason': 'BE'}
# {'ticker': 'MSTR', 'entry_date': Timestamp('2025-07-14 00:00:00'), 'entry_price': np.float64(451.23526375273264), 'exit_date': Timestamp('2025-07-21 00:00:00'), 'exit_price': np.float64(426.51572153967794), 'profit_pct': np.float64(-0.054951557793543555), 'profit_usd': np.float64(-644.6980975394221), 'reason': 'BE'}
# {'ticker': 'RIVN', 'entry_date': Timestamp('2025-07-21 00:00:00'), 'entry_price': np.float64(13.709167833940606), 'exit_date': Timestamp('2025-07-29 00:00:00'), 'exit_price': np.float64(13.067692550315213), 'profit_pct': np.float64(-0.047513845589718766), 'profit_usd': np.float64(-556.9258674997112), 'reason': 'BE'}
# {'ticker': 'VRSN', 'entry_date': Timestamp('2024-12-30 00:00:00'), 'entry_price': np.float64(204.1167202681279), 'exit_date': Timestamp('2025-07-30 00:00:00'), 'exit_price': np.float64(266.40431653370484), 'profit_pct': np.float64(0.30507047910778706), 'profit_usd': np.float64(7036.508378010196), 'reason': 'TSL'}
# {'ticker': 'NTES', 'entry_date': Timestamp('2025-05-19 00:00:00'), 'entry_price': np.float64(118.04048002334015), 'exit_date': Timestamp('2025-08-01 00:00:00'), 'exit_price': np.float64(126.83606256511317), 'profit_pct': np.float64(0.07338936501608119), 'profit_usd': np.float64(129.94373812659524), 'reason': 'TSL'}
# {'ticker': 'AMD', 'entry_date': Timestamp('2025-07-29 00:00:00'), 'entry_price': np.float64(177.50708598521385), 'exit_date': Timestamp('2025-08-04 00:00:00'), 'exit_price': np.float64(176.821594620878), 'profit_pct': np.float64(-0.004036938076914579), 'profit_usd': np.float64(-45.86144731749504), 'reason': 'BE'}
# {'ticker': 'CDNS', 'entry_date': Timestamp('2025-07-30 00:00:00'), 'entry_price': np.float64(371.3251275382003), 'exit_date': Timestamp('2025-08-04 00:00:00'), 'exit_price': np.float64(364.9598480362568), 'profit_pct': np.float64(-0.017237764809144906), 'profit_usd': np.float64(-358.44565210883707), 'reason': 'BE'}
# {'ticker': 'IDXX', 'entry_date': Timestamp('2025-08-04 00:00:00'), 'entry_price': np.float64(683.4066990882576), 'exit_date': Timestamp('2025-08-11 00:00:00'), 'exit_price': np.float64(652.3501658428982), 'profit_pct': np.float64(-0.04553763788863226), 'profit_usd': np.float64(-964.7425306061429), 'reason': 'BE'}
# {'ticker': 'MSFT', 'entry_date': Timestamp('2025-08-04 00:00:00'), 'entry_price': np.float64(535.0891249422237), 'exit_date': Timestamp('2025-08-11 00:00:00'), 'exit_price': np.float64(521.1382265359276), 'profit_pct': np.float64(-0.026258052633406092), 'profit_usd': np.float64(-281.0079681259224), 'reason': 'BE'}
# {'ticker': 'EA', 'entry_date': Timestamp('2025-08-11 00:00:00'), 'entry_price': np.float64(175.9876719721731), 'exit_date': Timestamp('2025-08-18 00:00:00'), 'exit_price': np.float64(169.01064006011362), 'profit_pct': np.float64(-0.03974002566634872), 'profit_usd': np.float64(-832.256797535079), 'reason': 'BE'}
# {'ticker': 'MU', 'entry_date': Timestamp('2025-08-11 00:00:00'), 'entry_price': np.float64(123.74967613306039), 'exit_date': Timestamp('2025-08-18 00:00:00'), 'exit_price': np.float64(123.51103530833001), 'profit_pct': np.float64(-0.0021176022243039674), 'profit_usd': np.float64(-22.274470102082464), 'reason': 'BE'}
# {'ticker': 'WBA', 'entry_date': Timestamp('2025-08-20 00:00:00'), 'entry_price': np.float64(12.206466463586635), 'exit_date': Timestamp('2025-08-25 00:00:00'), 'exit_price': np.float64(11.979040588644386), 'profit_pct': np.float64(-0.019442635233564147), 'profit_usd': np.float64(-401.55538040228475), 'reason': 'BE'}
# {'ticker': 'CEG', 'entry_date': Timestamp('2025-05-12 00:00:00'), 'entry_price': np.float64(284.7357944134174), 'exit_date': Timestamp('2025-08-29 00:00:00'), 'exit_price': np.float64(308.2300189303503), 'profit_pct': np.float64(0.0824772472506051), 'profit_usd': np.float64(4673.360678869645), 'reason': 'TSL'}
# {'ticker': 'EBAY', 'entry_date': Timestamp('2025-08-01 00:00:00'), 'entry_price': np.float64(91.51637231144453), 'exit_date': Timestamp('2025-08-29 00:00:00'), 'exit_price': np.float64(90.62645838411514), 'profit_pct': np.float64(-0.009896672641708027), 'profit_usd': np.float64(-114.11915484350293), 'reason': 'BE'}
# {'ticker': 'AXON', 'entry_date': Timestamp('2025-05-12 00:00:00'), 'entry_price': np.float64(693.4246411278863), 'exit_date': Timestamp('2025-09-02 00:00:00'), 'exit_price': np.float64(744.102001259037), 'profit_pct': np.float64(0.07294606396466381), 'profit_usd': np.float64(1062.2345627541656), 'reason': 'TSL'}
# {'ticker': 'PDD', 'entry_date': Timestamp('2025-08-25 00:00:00'), 'entry_price': np.float64(128.27256430894724), 'exit_date': Timestamp('2025-09-02 00:00:00'), 'exit_price': np.float64(121.79875322300293), 'profit_pct': np.float64(-0.050599548001452166), 'profit_usd': np.float64(-772.3735192273723), 'reason': 'BE'}
# {'ticker': 'MDB', 'entry_date': Timestamp('2025-08-29 00:00:00'), 'entry_price': np.float64(315.7971036346241), 'exit_date': Timestamp('2025-09-03 00:00:00'), 'exit_price': np.float64(313.1190337385431), 'profit_pct': np.float64(-0.008525684408931837), 'profit_usd': np.float64(-374.2417155552529), 'reason': 'BE'}
# {'ticker': 'TCOM', 'entry_date': Timestamp('2025-08-29 00:00:00'), 'entry_price': np.float64(73.79187537473533), 'exit_date': Timestamp('2025-09-03 00:00:00'), 'exit_price': np.float64(71.2810272051424), 'profit_pct': np.float64(-0.03416023995584722), 'profit_usd': np.float64(-753.7037027082869), 'reason': 'BE'}
# {'ticker': 'AVGO', 'entry_date': Timestamp('2025-05-12 00:00:00'), 'entry_price': np.float64(220.7924638316942), 'exit_date': Timestamp('2025-09-05 00:00:00'), 'exit_price': np.float64(334.52528807992866), 'profit_pct': np.float64(0.5148387732317793), 'profit_usd': np.float64(3751.1932001917376), 'reason': 'TP'}
# {'ticker': 'SNPS', 'entry_date': Timestamp('2025-07-10 00:00:00'), 'entry_price': np.float64(566.4248674521161), 'exit_date': Timestamp('2025-09-10 00:00:00'), 'exit_price': np.float64(387.9687195251257), 'profit_pct': np.float64(-0.31529126783748496), 'profit_usd': np.float64(-2678.832218904856), 'reason': 'TSL'}
# {'ticker': 'ADSK', 'entry_date': Timestamp('2025-09-02 00:00:00'), 'entry_price': np.float64(319.41714009011554), 'exit_date': Timestamp('2025-09-12 00:00:00'), 'exit_price': np.float64(319.20894086997373), 'profit_pct': np.float64(-0.0007277865951687796), 'profit_usd': np.float64(-19.06233605162821), 'reason': 'BE'}
# {'ticker': 'AVGO', 'entry_date': Timestamp('2025-09-10 00:00:00'), 'entry_price': np.float64(369.08871434001463), 'exit_date': Timestamp('2025-09-15 00:00:00'), 'exit_price': np.float64(363.7598375831239), 'profit_pct': np.float64(-0.014630488485994683), 'profit_usd': np.float64(-151.19854919294062), 'reason': 'BE'}
# {'ticker': 'ADI', 'entry_date': Timestamp('2025-08-20 00:00:00'), 'entry_price': np.float64(244.11137594712977), 'exit_date': Timestamp('2025-09-16 00:00:00'), 'exit_price': np.float64(244.25570064083058), 'profit_pct': np.float64(0.000397129142153759), 'profit_usd': np.float64(4.0716371354340115), 'reason': 'BE'}
# {'ticker': 'WBD', 'entry_date': Timestamp('2025-09-12 00:00:00'), 'entry_price': np.float64(18.882555028284), 'exit_date': Timestamp('2025-09-17 00:00:00'), 'exit_price': np.float64(18.000103600293862), 'profit_pct': np.float64(-0.047257981065247395), 'profit_usd': np.float64(-875.3967508583246), 'reason': 'BE'}
# {'ticker': 'PDD', 'entry_date': Timestamp('2025-09-17 00:00:00'), 'entry_price': np.float64(134.91479257260966), 'exit_date': Timestamp('2025-09-22 00:00:00'), 'exit_price': np.float64(128.62960834400275), 'profit_pct': np.float64(-0.046716855341743496), 'profit_usd': np.float64(-712.2158178325807), 'reason': 'BE'}
# {'ticker': 'WDC', 'entry_date': Timestamp('2025-09-03 00:00:00'), 'entry_price': np.float64(85.96093357922545), 'exit_date': Timestamp('2025-10-01 00:00:00'), 'exit_price': np.float64(130.6700097648499), 'profit_pct': np.float64(0.5199940754997465), 'profit_usd': np.float64(10191.412170322375), 'reason': 'TP'}
# {'ticker': 'APP', 'entry_date': Timestamp('2025-09-16 00:00:00'), 'entry_price': np.float64(604.1792186724424), 'exit_date': Timestamp('2025-10-06 00:00:00'), 'exit_price': np.float64(587.3331781175336), 'profit_pct': np.float64(-0.028047208561961225), 'profit_usd': np.float64(-338.9108110981754), 'reason': 'BE'}
# {'ticker': 'WDC', 'entry_date': Timestamp('2025-10-01 00:00:00'), 'entry_price': np.float64(130.6475768461613), 'exit_date': Timestamp('2025-10-06 00:00:00'), 'exit_price': np.float64(125.35835253847766), 'profit_pct': np.float64(-0.04057271727357554), 'profit_usd': np.float64(-917.0258052292671), 'reason': 'BE'}
# {'ticker': 'SMCI', 'entry_date': Timestamp('2025-10-06 00:00:00'), 'entry_price': np.float64(54.6390501175322), 'exit_date': Timestamp('2025-10-14 00:00:00'), 'exit_price': np.float64(53.139918998599256), 'profit_pct': np.float64(-0.027618179958965584), 'profit_usd': np.float64(-387.82099756576656), 'reason': 'BE'}
# {'ticker': 'CEG', 'entry_date': Timestamp('2025-10-14 00:00:00'), 'entry_price': np.float64(389.7329284896945), 'exit_date': Timestamp('2025-10-20 00:00:00'), 'exit_price': np.float64(370.1552275793467), 'profit_pct': np.float64(-0.05037952048161137), 'profit_usd': np.float64(-687.209531862173), 'reason': 'BE'}
# {'ticker': 'BIDU', 'entry_date': Timestamp('2025-09-05 00:00:00'), 'entry_price': np.float64(102.02312150400999), 'exit_date': Timestamp('2025-10-21 00:00:00'), 'exit_price': np.float64(119.17299538758172), 'profit_pct': np.float64(0.1679678779111999), 'profit_usd': np.float64(2570.4910825357597), 'reason': 'TSL'}
# {'ticker': 'NFLX', 'entry_date': Timestamp('2025-10-20 00:00:00'), 'entry_price': np.float64(1239.2997657201079), 'exit_date': Timestamp('2025-10-22 00:00:00'), 'exit_price': np.float64(1116.7353901649558), 'profit_pct': np.float64(-0.09905866114952355), 'profit_usd': np.float64(-1227.6337555515208), 'reason': 'SL'}
# {'ticker': 'GOOG', 'entry_date': Timestamp('2025-09-02 00:00:00'), 'entry_price': np.float64(211.84307395758972), 'exit_date': Timestamp('2025-10-27 00:00:00'), 'exit_price': np.float64(269.9927286864947), 'profit_pct': np.float64(0.274342497344739), 'profit_usd': np.float64(3603.288593192107), 'reason': 'EOD'}
# {'ticker': 'GOOGL', 'entry_date': Timestamp('2025-09-03 00:00:00'), 'entry_price': np.float64(230.51912688551883), 'exit_date': Timestamp('2025-10-27 00:00:00'), 'exit_price': np.float64(269.4483219493118), 'profit_pct': np.float64(0.16882512285061382), 'profit_usd': np.float64(6577.043965781008), 'reason': 'EOD'}
# {'ticker': 'TSLA', 'entry_date': Timestamp('2025-09-15 00:00:00'), 'entry_price': np.float64(410.3668326783362), 'exit_date': Timestamp('2025-10-27 00:00:00'), 'exit_price': np.float64(452.64180140713245), 'profit_pct': np.float64(0.10287488158216397), 'profit_usd': np.float64(1435.358936779072), 'reason': 'EOD'}
# {'ticker': 'AMAT', 'entry_date': Timestamp('2025-09-22 00:00:00'), 'entry_price': np.float64(200.58404592915508), 'exit_date': Timestamp('2025-10-27 00:00:00'), 'exit_price': np.float64(231.39914623030643), 'profit_pct': np.float64(0.15349280779855065), 'profit_usd': np.float64(2278.3274222851996), 'reason': 'EOD'}
# {'ticker': 'AMD', 'entry_date': Timestamp('2025-10-06 00:00:00'), 'entry_price': np.float64(203.80961164218937), 'exit_date': Timestamp('2025-10-27 00:00:00'), 'exit_price': np.float64(259.8528330356218), 'profit_pct': np.float64(0.2749070340428883), 'profit_usd': np.float64(7675.9313309002455), 'reason': 'EOD'}
# {'ticker': 'PCAR', 'entry_date': Timestamp('2025-10-21 00:00:00'), 'entry_price': np.float64(99.90295688353498), 'exit_date': Timestamp('2025-10-27 00:00:00'), 'exit_price': np.float64(101.10115237001003), 'profit_pct': np.float64(0.011870634992718716), 'profit_usd': np.float64(192.11766880895703), 'reason': 'EOD'}
# {'ticker': 'WBD', 'entry_date': Timestamp('2025-10-22 00:00:00'), 'entry_price': np.float64(20.54594352016357), 'exit_date': Timestamp('2025-10-27 00:00:00'), 'exit_price': np.float64(21.04870798429629), 'profit_pct': np.float64(0.023988407426946773), 'profit_usd': np.float64(329.7263265047901), 'reason': 'EOD'}
